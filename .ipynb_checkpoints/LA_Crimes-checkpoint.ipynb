# %% [markdown]
# # LA County Crime
#
# ##### The following data is a 30-day (Aug 2017) download of Part I and Part II Crimes that occurred in the Los Angeles County Sheriff’s Department’s jurisdiction.
#
# * For more information, Please Visit [Los Angeles County Sheriff's Department](http://shq.lasdnews.net/CrimeStats/CAASS/desc.html)

# %% [markdown]
# # Introducing LA County Crime Data

# %%
import csv
import os
import datetime
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import matplotlib.style as style
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')  #suppress deprecation and incorrect usage warnings

# %matplotlib inline

# %%
path = "/Users/DonginKim/Documents/Python/Data"
os.chdir(path)
df = pd.read_csv('LA_crimes.csv')
df.columns = map(str.lower, df.columns)  #change column name to lower case
df.head()
# Out:
#    lurn_sak        incident_date           category  stat  \
# 0  18278123  2017-07-24 22:56:00  CRIMINAL HOMICIDE    11
# 1  18280263  2017-07-26 14:20:00  CRIMINAL HOMICIDE    11
# 2  18282808  2017-07-28 20:30:00  CRIMINAL HOMICIDE    11
# 3  18284349  2017-07-30 20:55:00  CRIMINAL HOMICIDE    11
# 4  18287795  2017-08-03 00:44:00  CRIMINAL HOMICIDE    11
#
#                    stat_desc  \
# 0  CRIMINAL HOMICIDE: Murder
# 1  CRIMINAL HOMICIDE: Murder
# 2  CRIMINAL HOMICIDE: Murder
# 3  CRIMINAL HOMICIDE: Murder
# 4  CRIMINAL HOMICIDE: Murder
#
#                                              address  \
# 0      S CRANE AVE & E CYPRESS ST, COMPTON, CA 90221
# 1              14800 CLARK AVE, HACIENDA HEIGHTS, CA
# 2  ARTESIA BLVD & SAN GABRIEL RIVERBED, CERRITOS, CA
# 3             15000 S AVALON BLVD, GARDENA, CA 90248
# 4             44700 DIVISION ST, LANCASTER, CA 93535
#
#                                 street              city      zip  \
# ...

# %%
msno.matrix(df,figsize=(12,6))  #to visualize NAs

# %% [markdown]
# # Crime by Category

# %%
category_count = pd.DataFrame(df['category'].value_counts())
category_percent = pd.DataFrame(df['category'].value_counts(normalize=True))  #to get percentile
category_df = category_count.merge(category_percent, left_index=True, right_index=True)  #merge

category_df.reset_index(inplace=True)
category_df.columns = ['category', 'count', 'percentile']
category_df
# Out:
#                         category  count  percentile
# 0                  LARCENY THEFT   2187    0.190838
# 1         VEHICLE / BOATING LAWS   1458    0.127225
# 2                      NARCOTICS   1156    0.100873
# 3        NON-AGGRAVATED ASSAULTS   1055    0.092059
# 4               GRAND THEFT AUTO    927    0.080890
# 5                       BURGLARY    884    0.077138
# 6                      VANDALISM    792    0.069110
# 7             AGGRAVATED ASSAULT    543    0.047382
# 8                        ROBBERY    377    0.032897
# 9     MISDEMEANORS MISCELLANEOUS    373    0.032548
# 10          FRAUD AND NSF CHECKS    290    0.025305
# 11                   WEAPON LAWS    271    0.023647
# 12                   LIQUOR LAWS    137    0.011955
# 13        FELONIES MISCELLANEOUS    132    0.011518
# 14  DRUNK DRIVING VEHICLE / BOAT    131    0.011431
# 15       DRUNK / ALCOHOL / DRUGS    120    0.010471
# 16                       FORGERY    104    0.009075
# ...

# %%
category_new = category_df[category_df['percentile'] >= 0.08]
category_temp = category_df[category_df['percentile'] < 0.08]

category_new.loc['10'] = category_temp.sum(axis=0)
category_new.ix['10','category'] = 'OTHERS'
category_new
# Out:
#                    category  count  percentile
# 0             LARCENY THEFT   2187    0.190838
# 1    VEHICLE / BOATING LAWS   1458    0.127225
# 2                 NARCOTICS   1156    0.100873
# 3   NON-AGGRAVATED ASSAULTS   1055    0.092059
# 4          GRAND THEFT AUTO    927    0.080890
# 10                   OTHERS   4677    0.408115

# %% [markdown]
# ## Pie Chart

# %%
plt.figure(figsize = (5,5))
colors = ['lightgrey', 'yellowgreen', 'lightcoral', 'lightskyblue', 'yellow', 'gold']
explode = (0, 0, 0, 0, 0, 0.15)

plt.pie(category_new['percentile'],colors=colors, explode=explode, shadow=True,
        autopct='%1.1f%%', startangle=90)
plt.title('Crimes in Los Angeles', y=1.05, fontsize=15) #distance from plot and size
plt.legend(loc="upper left", labels=category_new['category'], prop={'size':7}) 
plt.tight_layout()
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Count Plot

# %%
plt.figure(figsize = (8,12))
sns.countplot(y='category', data=df, order = df['category'].value_counts().index)  #palette="Set3"

# %% [markdown]
# # Exploring Crimes by City

# %%
city_count = pd.DataFrame(df['city'].value_counts())
city_percent = pd.DataFrame(df['city'].value_counts(normalize=True))  #to get percentile
city_df = city_count.merge(city_percent, left_index=True, right_index=True)  #merge

city_df.reset_index(inplace=True)
city_df.columns = ['city', 'count', 'percentile']
city_df.describe()
# Out:
#              count  percentile
# count   156.000000  156.000000
# mean     72.602564    0.006410
# std     173.994649    0.015362
# min       1.000000    0.000088
# 25%       2.000000    0.000177
# 50%      15.000000    0.001324
# 75%      63.750000    0.005629
# max    1564.000000    0.138089

# %%
city_new = city_df[city_df['count'] >= 150]
city_temp = city_df[city_df['count'] < 150]

# %% [markdown]
# ## Count Plot

# %%
plt.figure(figsize = (8,12))
sns.barplot(x='count', y='city', data=city_new)  #palette="Set3"

# %%
city_new.loc['18'] = city_temp.sum(axis=0)
city_new.ix['18','city'] = 'OTHERS'
city_new
# Out:
#               city  count  percentile
# 0      LOS ANGELES   1564    0.138089
# 1        LANCASTER    963    0.085026
# 2         PALMDALE    655    0.057832
# 3          COMPTON    647    0.057125
# 4           CARSON    373    0.032933
# 5          NORWALK    360    0.031785
# 6         WHITTIER    295    0.026046
# 7          LYNWOOD    293    0.025870
# 8   WEST HOLLYWOOD    291    0.025693
# 9       BELLFLOWER    284    0.025075
# 10        CERRITOS    268    0.023662
# 11        LAKEWOOD    255    0.022515
# 12     PICO RIVERA    242    0.021367
# 13       PARAMOUNT    240    0.021190
# 14        ROSEMEAD    233    0.020572
# 15        VALENCIA    164    0.014480
# 16  CANYON COUNTRY    161    0.014215
# 17       LA PUENTE    157    0.013862
# 18          OTHERS   3881    0.342663

# %% [markdown]
# # 5 Most Dangerous Cities

# %%
# Convert and Deal with Datetime Objects
df['incident_date'] = pd.to_datetime(df['incident_date'])
df['incident_date'] = df['incident_date'].apply(lambda x: x.date())  #display only date
#df = df.set_index('incident_date')

# %%
df_la = df[df['city'] == 'LOS ANGELES'] 
df_la = pd.DataFrame(df_la['incident_date'].value_counts())

df_lctr = df[df['city'] == 'LANCASTER'] 
df_lctr = pd.DataFrame(df_lctr['incident_date'].value_counts())

df_pmdl = df[df['city'] == 'PALMDALE'] 
df_pmdl = pd.DataFrame(df_pmdl['incident_date'].value_counts())

df_cmtn = df[df['city'] == 'COMPTON'] 
df_cmtn = pd.DataFrame(df_cmtn['incident_date'].value_counts())

df_crsn = df[df['city'] == 'CARSON'] 
df_crsn = pd.DataFrame(df_crsn['incident_date'].value_counts())

city_df = pd.concat([df_la, df_lctr, df_pmdl, df_cmtn, df_crsn], axis=1)

city_df.columns = ['los angeles', 'lancaster', 'palmdale', 'compton', 'carson']
city_df.fillna(0, inplace=True)
city_df.tail()
# Out:
#             los angeles  lancaster  palmdale  compton  carson
# 2017-08-17           45         27        22       30    16.0
# 2017-08-18           46         23        27       15     7.0
# 2017-08-19           28         16        12       23     3.0
# 2017-08-20           20          8        12       15     0.0
# 2017-08-21            7          3         1       10     0.0

# %% [markdown]
# ## Line Chart

# %%
style.use('fivethirtyeight')
plt.figure(figsize=(18,10))
plt.plot(city_df)
plt.tick_params(axis = 'both', labelsize = 15)
plt.xlim(left=datetime.datetime(2017,7,22) , right=datetime.datetime(2017,8,21))
plt.yticks([0, 20, 40, 60, 80])
plt.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .7)
plt.legend(loc="best", labels=city_df, prop={'size':20})

# %% [markdown]
# # Findings
#
# It appears that crimes in Los Angeles County are primarily in the level of misdemeanour and disproportionately concentrated in the city of Los Angeles.
#
# Some areas to investigate further:
#
# * The link between day of the week and crime rate.
# * Crime rate by gender.
# * The rates of other intents by gender and race.
# * Crime rates by location and education.
